# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as sts
import re

# %%
#Dataset PIB

df_1 = pd.read_csv('PIB-municipios-BHRP.csv')
df_1 = df_1[(df_1['Ano'] == 2019)]
df_1.head()
# Out:
#      Ano  Código da Grande Região Nome da Grande Região  \
# 17  2019                        3               Sudeste
# 35  2019                        3               Sudeste
# 53  2019                        3               Sudeste
# 71  2019                        3               Sudeste
# 89  2019                        3               Sudeste
#
#     Código da Unidade da Federação Sigla da Unidade da Federação  \
# 17                              31                            MG
# 35                              31                            MG
# 53                              31                            MG
# 71                              31                            MG
# 89                              31                            MG
#
#    Nome da Unidade da Federação  Código do Município   Nome do Município  \
# 17                 Minas Gerais              3106408           Belo Vale
# 35                 Minas Gerais              3106705               Betim
# 53                 Minas Gerais              3108107              Bonfim
# 71                 Minas Gerais              3109006          Brumadinho
# 89                 Minas Gerais              3109600  Cachoeira da Prata
#
#                       Região Metropolitana  Código da Mesorregião  ...  \
# 17  Região Metropolitana de Belo Horizonte                   3107  ...
# 35  Região Metropolitana de Belo Horizonte                   3107  ...
# 53  Região Metropolitana de Belo Horizonte                   3107  ...
# 71  Região Metropolitana de Belo Horizonte                   3107  ...
# 89                                     NaN                   3107  ...
#
#    Valor adicionado bruto da Indústria a preços correntes (R$ 1.000)  \
# 17                                            63,197
# 35                                        11,537,468
# 53                                             9,781
# 71                                         1,041,129
# 89                                             2,273
#
#     Valor adicionado bruto dos Serviços a preços correntes - exceto Administração em defesa educação e saúde públicas e seguridade social (R$ 1.000)  \
# 17                                            51,778
# 35                                         9,924,629
# 53                                            41,414
# 71                                           982,042
# 89                                            18,942
#
#    Valor adicionado bruto da Administração, defesa, educação e saúde públicas e seguridade social a preços correntes (R$ 1.000)  \
# 17                                            49,607
# 35                                         2,212,077
# 53                                            30,739
# 71                                           255,486
# 89                                            19,154
#
#     Valor adicionado bruto total a preços correntes (R$ 1.000)  \
# 17                                           181,944
# 35                                        23,687,150
# 53                                            96,526
# 71                                         2,300,665
# 89                                            41,662
#
#    Impostos, líquidos de subsídios, sobre produtos a preços correntes (R$ 1.000)  \
# 17                                             6,005
# 35                                         4,379,098
# 53                                             5,797
# 71                                           215,568
# 89                                             5,085
#
#    Produto Interno Bruto a preços correntes (R$ 1.000)  \
# 17                                           187,949
# 35                                        28,066,248
# 53                                           102,323
# 71                                         2,516,233
# 89                                            46,748
#
#     Produto Interno Bruto per capita a preços correntes (R$ 1,00)  \
# 17                                         24,361.53
# 35                                         63,882.75
# 53                                         14,898.51
# 71                                         62,744.25
# 89                                         12,974.72
#
#            Atividade com maior valor adicionado bruto  \
# 17                              Indústrias extrativas
# 35                        Indústrias de transformação
# 53                                    Demais serviços
# 71                                    Demais serviços
# 89  Administração, defesa, educação e saúde públic...
#
#    Atividade com segundo maior valor adicionado bruto  \
# 17  Administração, defesa, educação e saúde públic...
# 35                                    Demais serviços
# 53  Administração, defesa, educação e saúde públic...
# 71                              Indústrias extrativas
# 89                                    Demais serviços
#
#     Atividade com terceiro maior valor adicionado bruto
# 17                                    Demais serviços
# 35  Comércio e reparação de veículos automotores e...
# 53  Agricultura, inclusive apoio à agricultura e a...
# 71  Administração, defesa, educação e saúde públic...
# 89  Comércio e reparação de veículos automotores e...
#
# [5 rows x 43 columns]

# %%
#Dataset CAR

df_2 = pd.read_csv('CAR-recursos-naturais.csv')
df_2.head()
# Out:
#    Nome do Município   APP  Altitude Superior 1800  Consolidada  \
# 0          Belo Vale  4489                       0          844
# 1              Betim  2664                       0          446
# 2             Bonfim  6133                       0         1749
# 3         Brumadinho  7419                       0          787
# 4  Cahoeira da Prata   330                       0           67
#
#    Declividade Maior 45  Imoveis  Pousio  Topo de Morro  Banhado  \
# 0                     3     1055      47              2        3
# 1                     2      741       9              1        3
# 2                     1     2064      41              1        0
# 3                    15     1177      44              8        1
# 4                     0       61       1              0        1
#
#    Borda Chapada  Hidrografia  Manguezal  Nascentes  Reserva Legal  Restinga  \
# 0              0          948          0        412            859         0
# 1              0          436          0        247            586         0
# 2              0         1291          0        383           1650         0
# 3              0          965          0        726           1025         1
# 4              0           61          0         28             86         0
#
#    Servidão Administrativa  Restrito  Vegetação Nativa  Vereda
# 0                       99         0               904      24
# 1                       57         3               637       4
# 2                      413        29              1507      30
# 3                      191        23               949      31
# 4                       12         0               113       0

# %%
#Dataser IDHM
#https://www.br.undp.org/content/brazil/pt/home/idh0/rankings/idhm-municipios-2010.html

df_3 = pd.read_csv('IDH-cidades.csv')
df_3.head()
# Out:
#     Nome do Município  IDH 2010  IDHM Renda 2010  IDHM Longevidade 2010  \
# 0           Belo Vale     0.655            0.672                  0.814
# 1               Betim     0.749            0.709                  0.864
# 2              Bonfim     0.637            0.669                  0.834
# 3          Brumadinho     0.747            0.761                  0.857
# 4  Cachoeira da Prata     0.741            0.689                  0.834
#
#    IDHM Educação 2010
# 0               0.514
# 1               0.687
# 2               0.464
# 3               0.639
# 4               0.707

# %%
#União dos datasets - merge com pandas

df = pd.merge(df_1, df_2, how='inner', on="Nome do Município")
df = pd.merge(df, df_3, how='inner', on="Nome do Município")
df.head()
# Out:
#     Ano  Código da Grande Região Nome da Grande Região  \
# 0  2019                        3               Sudeste
# 1  2019                        3               Sudeste
# 2  2019                        3               Sudeste
# 3  2019                        3               Sudeste
# 4  2019                        3               Sudeste
#
#    Código da Unidade da Federação Sigla da Unidade da Federação  \
# 0                              31                            MG
# 1                              31                            MG
# 2                              31                            MG
# 3                              31                            MG
# 4                              31                            MG
#
#   Nome da Unidade da Federação  Código do Município Nome do Município  \
# 0                 Minas Gerais              3106408         Belo Vale
# 1                 Minas Gerais              3106705             Betim
# 2                 Minas Gerais              3108107            Bonfim
# 3                 Minas Gerais              3109006        Brumadinho
# 4                 Minas Gerais              3114907       Casa Grande
#
#                      Região Metropolitana  Código da Mesorregião  ...  \
# 0  Região Metropolitana de Belo Horizonte                   3107  ...
# 1  Região Metropolitana de Belo Horizonte                   3107  ...
# 2  Região Metropolitana de Belo Horizonte                   3107  ...
# 3  Região Metropolitana de Belo Horizonte                   3107  ...
# 4                                     NaN                   3107  ...
#
#   Reserva Legal  Restinga Servidão Administrativa  Restrito Vegetação Nativa  \
# 0           859         0                      99         0              904
# 1           586         0                      57         3              637
# 2          1650         0                     413        29             1507
# 3          1025         1                     191        23              949
# 4           776         0                     117        30              692
#
#   Vereda  IDH 2010 IDHM Renda 2010 IDHM Longevidade 2010  IDHM Educação 2010
# 0     24     0.655           0.672                 0.814               0.514
# 1      4     0.749           0.709                 0.864               0.687
# 2     30     0.637           0.669                 0.834               0.464
# 3     31     0.747           0.761                 0.857               0.639
# 4      5     0.652           0.608                 0.823               0.555
#
# [5 rows x 65 columns]

# %%
df.head()
# Out:
#       Nome da cidade   APP  Altitude Superior 1800  Consolidada  \
# 0          Belo Vale  4489                       0          844
# 1              Betim  2664                       0          466
# 2             Bonfim  6133                       0         1749
# 3         Brumadinho  7419                       0          787
# 4  Cahoeira da Prata   330                       0           67
#
#    Declividade Maior 45  Imoveis  Pousio  Topo de Morro  Banhado  \
# 0                     3     1055      47              2        3
# 1                     2      741       9              1        3
# 2                     1     2064      41              1        0
# 3                    15     1177      44              8        1
# 4                     0       61       1              0        1
#
#    Borda Chapada  Hidrografia  Manguezal  Nascentes  Reserva Legal  Restinga  \
# 0              0          948          0        412            859         0
# 1              0          436          0        247              0         0
# 2              0         1291          0        383           1650         0
# 3              0          965          0        726           1025         1
# 4              0           61          0         28             86         0
#
#    Servidão Administrativa  Restrito  Vegetação Nativa  Vereda
# 0                       99         0               904      24
# 1                        0         3               637       4
# 2                      413        29              1507      30
# 3                      191        23               949      31
# 4                       12         0               113       0

# %%
#

t = []
for i in df:
    x = []
    for j in df[i]:
        x.append(j)
    t.append(x)

aux = t[1:]
aux
# Out:
# [[3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3],
#  ['Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste',
#   'Sudeste'],
#  [31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31,
#   31],
#  ['MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG',
#   'MG'],
#  ['Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais',
#   'Minas Gerais'],
#  [3106408,
#   3106705,
#   3108107,
#   3109006,
#   3109600,
#   3109907,
#   3114907,
#   3118007,
#   3118304,
#   3118601,
#   3120409,
#   3120607,
#   3120904,
#   3121407,
#   3123908,
#   3124104,
#   3125705,
#   3126000,
#   3126406,
#   3129806,
#   3130101,
#   3131000,
#   3133709,
#   3133808,
#   3133907,
#   3135407,
#   3136652,
#   3137403,
#   3139706,
#   3140159,
#   3140704,
#   3142304,
#   3145901,
#   3146107,
#   3146909,
#   3147105,
#   3147402,
#   3149606,
#   3150406,
#   3152006,
#   3153806,
#   3154200,
#   3155306,
#   3160900,
#   3162922,
#   3163102,
#   3165537,
#   3167202],
#  ['Belo Vale',
#   'Betim',
#   'Bonfim',
#   'Brumadinho',
#   'Cachoeira da Prata',
#   'Caetanópolis',
#   'Casa Grande',
#   'Congonhas',
#   'Conselheiro Lafaiete',
#   'Contagem',
#   'Cristiano Otoni',
#   'Crucilândia',
#   'Curvelo',
#   'Desterro de Entre Rios',
#   'Entre Rios de Minas',
#   'Esmeraldas',
#   'Felixlândia',
#   'Florestal',
#   'Fortuna de Minas',
#   'Ibirité',
#   'Igarapé',
#   'Inhaúma',
#   'Itatiaiuçu',
#   'Itaúna',
#   'Itaverava',
#   'Jeceaba',
#   'Juatuba',
#   'Lagoa Dourada',
#   'Maravilhas',
#   'Mário Campos',
#   'Mateus Leme',
#   'Moeda',
#   'Ouro Branco',
#   'Ouro Preto',
#   'Papagaios',
#   'Pará de Minas',
#   'Paraopeba',
#   'Pequi',
#   'Piedade dos Gerais',
#   'Pompéu',
#   'Queluzito',
#   'Resende Costa',
#   'Rio Manso',
#   'São Brás do Suaçuí',
#   'São Joaquim de Bicas',
#   'São José da Varginha',
#   'Sarzedo',
#   'Sete Lagoas'],
#  ['Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'Região Metropolitana de Belo Horizonte',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'Região Metropolitana de Belo Horizonte',
#   nan,
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   nan,
#   nan,
#   'Região Metropolitana de Belo Horizonte',
#   nan,
#   nan,
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   nan,
#   nan,
#   nan,
#   'Região Metropolitana de Belo Horizonte',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'Região Metropolitana de Belo Horizonte',
#   nan,
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte',
#   'Região Metropolitana de Belo Horizonte'],
#  [3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3106,
#   3107,
#   3107,
#   3107,
#   3106,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3109,
#   3107,
#   3107,
#   3107,
#   3111,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3106,
#   3107,
#   3111,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107,
#   3107],
#  ['Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Central Mineira',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Central Mineira',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Oeste de Minas',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Campo das Vertentes',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Central Mineira',
#   'Metropolitana de Belo Horizonte',
#   'Campo das Vertentes',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte',
#   'Metropolitana de Belo Horizonte'],
#  [31032,
#   31030,
#   31032,
#   31030,
#   31027,
#   31027,
#   31034,
#   31034,
#   31034,
#   31030,
#   31034,
#   31032,
#   31025,
#   31034,
#   31034,
#   31030,
#   31025,
#   31029,
#   31027,
#   31030,
#   31030,
#   31027,
#   31032,
#   31043,
#   31034,
#   31032,
#   31030,
#   31058,
#   31027,
#   31030,
#   31030,
#   31032,
#   31034,
#   31033,
#   31027,
#   31029,
#   31027,
#   31027,
#   31032,
#   31024,
#   31034,
#   31058,
#   31032,
#   31034,
#   31030,
#   31029,
#   31030,
#   31027],
#  ['Itaguara',
#   'Belo Horizonte',
#   'Itaguara',
#   'Belo Horizonte',
#   'Sete Lagoas',
#   'Sete Lagoas',
#   'Conselheiro Lafaiete',
#   'Conselheiro Lafaiete',
#   'Conselheiro Lafaiete',
#   'Belo Horizonte',
#   'Conselheiro Lafaiete',
#   'Itaguara',
#   'Curvelo',
#   'Conselheiro Lafaiete',
#   'Conselheiro Lafaiete',
#   'Belo Horizonte',
#   'Curvelo',
#   'Pará de Minas',
#   'Sete Lagoas',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Sete Lagoas',
#   'Itaguara',
#   'Divinópolis',
#   'Conselheiro Lafaiete',
#   'Itaguara',
#   'Belo Horizonte',
#   'São João Del Rei',
#   'Sete Lagoas',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Itaguara',
#   'Conselheiro Lafaiete',
#   'Ouro Preto',
#   'Sete Lagoas',
#   'Pará de Minas',
#   'Sete Lagoas',
#   'Sete Lagoas',
#   'Itaguara',
#   'Três Marias',
#   'Conselheiro Lafaiete',
#   'São João Del Rei',
#   'Itaguara',
#   'Conselheiro Lafaiete',
#   'Belo Horizonte',
#   'Pará de Minas',
#   'Belo Horizonte',
#   'Sete Lagoas'],
#  [310038,
#   310001,
#   310069,
#   310001,
#   310002,
#   310002,
#   310038,
#   310038,
#   310038,
#   310001,
#   310038,
#   310069,
#   310004,
#   310038,
#   310038,
#   310001,
#   310004,
#   310001,
#   310002,
#   310001,
#   310001,
#   310002,
#   310065,
#   310065,
#   310038,
#   310038,
#   310001,
#   310039,
#   310068,
#   310001,
#   310001,
#   310001,
#   310038,
#   310003,
#   310068,
#   310068,
#   310002,
#   310068,
#   310069,
#   310067,
#   310038,
#   310039,
#   310069,
#   310038,
#   310001,
#   310068,
#   310001,
#   310002],
#  ['Conselheiro Lafaiete',
#   'Belo Horizonte',
#   'Oliveira',
#   'Belo Horizonte',
#   'Sete Lagoas',
#   'Sete Lagoas',
#   'Conselheiro Lafaiete',
#   'Conselheiro Lafaiete',
#   'Conselheiro Lafaiete',
#   'Belo Horizonte',
#   'Conselheiro Lafaiete',
#   'Oliveira',
#   'Curvelo',
#   'Conselheiro Lafaiete',
#   'Conselheiro Lafaiete',
#   'Belo Horizonte',
#   'Curvelo',
#   'Belo Horizonte',
#   'Sete Lagoas',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Sete Lagoas',
#   'Divinópolis',
#   'Divinópolis',
#   'Conselheiro Lafaiete',
#   'Conselheiro Lafaiete',
#   'Belo Horizonte',
#   'São João del Rei',
#   'Pará de Minas',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Conselheiro Lafaiete',
#   'Santa Bárbara - Ouro Preto',
#   'Pará de Minas',
#   'Pará de Minas',
#   'Sete Lagoas',
#   'Pará de Minas',
#   'Oliveira',
#   'Dores do Indaiá',
#   'Conselheiro Lafaiete',
#   'São João del Rei',
#   'Oliveira',
#   'Conselheiro Lafaiete',
#   'Belo Horizonte',
#   'Pará de Minas',
#   'Belo Horizonte',
#   'Sete Lagoas'],
#  ['do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'Polo',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'Polo',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'Polo',
#   'do Entorno',
#   'Polo',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'Polo'],
#  [3107,
#   3101,
#   3113,
#   3101,
#   3101,
#   3101,
#   3107,
#   3107,
#   3107,
#   3101,
#   3107,
#   3113,
#   3101,
#   3107,
#   3107,
#   3101,
#   3101,
#   3101,
#   3101,
#   3101,
#   3101,
#   3101,
#   3113,
#   3113,
#   3107,
#   3107,
#   3101,
#   3107,
#   3113,
#   3101,
#   3101,
#   3101,
#   3107,
#   3101,
#   3113,
#   3113,
#   3101,
#   3113,
#   3113,
#   3113,
#   3107,
#   3107,
#   3113,
#   3107,
#   3101,
#   3113,
#   3101,
#   3101],
#  ['Barbacena',
#   'Belo Horizonte',
#   'Divinópolis',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Barbacena',
#   'Barbacena',
#   'Barbacena',
#   'Belo Horizonte',
#   'Barbacena',
#   'Divinópolis',
#   'Belo Horizonte',
#   'Barbacena',
#   'Barbacena',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Divinópolis',
#   'Divinópolis',
#   'Barbacena',
#   'Barbacena',
#   'Belo Horizonte',
#   'Barbacena',
#   'Divinópolis',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Belo Horizonte',
#   'Barbacena',
#   'Belo Horizonte',
#   'Divinópolis',
#   'Divinópolis',
#   'Belo Horizonte',
#   'Divinópolis',
#   'Divinópolis',
#   'Divinópolis',
#   'Barbacena',
#   'Barbacena',
#   'Divinópolis',
#   'Barbacena',
#   'Belo Horizonte',
#   'Divinópolis',
#   'Belo Horizonte',
#   'Belo Horizonte'],
#  ['do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno',
#   'do Entorno'],
#  [nan,
#   3106200.0,
#   nan,
#   3106200.0,
#   nan,
#   nan,
#   nan,
#   3118304.0,
#   3118304.0,
#   3106200.0,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   3106200.0,
#   nan,
#   nan,
#   nan,
#   3106200.0,
#   3106200.0,
#   3167202.0,
#   nan,
#   nan,
#   nan,
#   3118304.0,
#   3106200.0,
#   nan,
#   nan,
#   3106200.0,
#   nan,
#   nan,
#   3118304.0,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   3118304.0,
#   nan,
#   nan,
#   3118304.0,
#   3106200.0,
#   nan,
#   3106200.0,
#   3167202.0],
#  [nan,
#   'Belo Horizonte/MG',
#   nan,
#   'Belo Horizonte/MG',
#   nan,
#   nan,
#   nan,
#   'Conselheiro Lafaiete/MG',
#   'Conselheiro Lafaiete/MG',
#   'Belo Horizonte/MG',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'Belo Horizonte/MG',
#   nan,
#   nan,
#   nan,
#   'Belo Horizonte/MG',
#   'Belo Horizonte/MG',
#   'Sete Lagoas/MG',
#   nan,
#   nan,
#   nan,
#   'Conselheiro Lafaiete/MG',
#   'Belo Horizonte/MG',
#   nan,
#   nan,
#   'Belo Horizonte/MG',
#   nan,
#   nan,
#   'Conselheiro Lafaiete/MG',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'Conselheiro Lafaiete/MG',
#   nan,
#   nan,
#   'Conselheiro Lafaiete/MG',
#   'Belo Horizonte/MG',
#   nan,
#   'Belo Horizonte/MG',
#   'Sete Lagoas/MG'],
#  [nan,
#   'Grande concentração urbana',
#   nan,
#   'Grande concentração urbana',
#   nan,
#   nan,
#   nan,
#   'Média concentração urbana',
#   'Média concentração urbana',
#   'Grande concentração urbana',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'Grande concentração urbana',
#   nan,
#   nan,
#   nan,
#   'Grande concentração urbana',
#   'Grande concentração urbana',
#   'Média concentração urbana',
#   nan,
#   nan,
#   nan,
#   'Média concentração urbana',
#   'Grande concentração urbana',
#   nan,
#   nan,
#   'Grande concentração urbana',
#   nan,
#   nan,
#   'Média concentração urbana',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   'Média concentração urbana',
#   nan,
#   nan,
#   'Média concentração urbana',
#   'Grande concentração urbana',
#   nan,
#   'Grande concentração urbana',
#   'Média concentração urbana'],
#  [nan,
#   3106200.0,
#   nan,
#   3106200.0,
#   nan,
#   3147402.0,
#   nan,
#   3118304.0,
#   3118304.0,
#   3106200.0,
#   nan,
#   nan,
#   3120904.0,
#   nan,
#   nan,
#   3106200.0,
#   nan,
#   nan,
#   nan,
#   3106200.0,
#   3106200.0,
#   3167202.0,
#   3133808.0,
#   3133808.0,
#   nan,
#   3118304.0,
#   3106200.0,
#   nan,
#   nan,
#   3106200.0,
#   nan,
#   nan,
#   3118304.0,
#   nan,
#   nan,
#   nan,
#   3147402.0,
#   nan,
#   nan,
#   nan,
#   3118304.0,
#   nan,
#   nan,
#   3118304.0,
#   3106200.0,
#   nan,
#   3106200.0,
#   3167202.0],
#  [nan,
#   'Belo Horizonte/MG',
#   nan,
#   'Belo Horizonte/MG',
#   nan,
#   'Paraopeba/MG',
#   nan,
#   'Conselheiro Lafaiete/MG',
#   'Conselheiro Lafaiete/MG',
#   'Belo Horizonte/MG',
#   nan,
#   nan,
#   'Curvelo/MG',
#   nan,
#   nan,
#   'Belo Horizonte/MG',
#   nan,
#   nan,
#   nan,
#   'Belo Horizonte/MG',
#   'Belo Horizonte/MG',
#   'Sete Lagoas/MG',
#   'Itaúna/MG',
#   'Itaúna/MG',
#   nan,
#   'Conselheiro Lafaiete/MG',
#   'Belo Horizonte/MG',
#   nan,
#   nan,
#   'Belo Horizonte/MG',
#   nan,
#   nan,
#   'Conselheiro Lafaiete/MG',
#   nan,
#   nan,
#   nan,
#   'Paraopeba/MG',
#   nan,
#   nan,
#   nan,
#   'Conselheiro Lafaiete/MG',
#   nan,
#   nan,
#   'Conselheiro Lafaiete/MG',
#   'Belo Horizonte/MG',
#   nan,
#   'Belo Horizonte/MG',
#   'Sete Lagoas/MG'],
#  ['Centro Local',
#   'Integrante de Metrópole',
#   'Centro Local',
#   'Integrante de Metrópole',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro de Zona B',
#   'Centro Subregional B',
#   'Integrante de Metrópole',
#   'Centro Local',
#   'Centro Local',
#   'Centro de Zona A',
#   'Centro Local',
#   'Centro de Zona B',
#   'Integrante de Metrópole',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Integrante de Metrópole',
#   'Integrante de Metrópole',
#   'Centro Local',
#   'Centro Local',
#   'Centro de Zona B',
#   'Centro Local',
#   'Centro Local',
#   'Integrante de Metrópole',
#   'Centro Local',
#   'Centro Local',
#   'Integrante de Metrópole',
#   'Integrante de Metrópole',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro de Zona A',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Integrante de Metrópole',
#   'Centro Local',
#   'Integrante de Metrópole',
#   'Integrante de Metrópole'],
#  ['Centro Local',
#   'Metrópole',
#   'Centro Local',
#   'Metrópole',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro de Zona',
#   'Centro Subregional',
#   'Metrópole',
#   'Centro Local',
#   'Centro Local',
#   'Centro de Zona',
#   'Centro Local',
#   'Centro de Zona',
#   'Metrópole',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Metrópole',
#   'Metrópole',
#   'Centro Local',
#   'Centro Local',
#   'Centro de Zona',
#   'Centro Local',
#   'Centro Local',
#   'Metrópole',
#   'Centro Local',
#   'Centro Local',
#   'Metrópole',
#   'Metrópole',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro de Zona',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Centro Local',
#   'Metrópole',
#   'Centro Local',
#   'Metrópole',
#   'Metrópole'],
#  [3108,
#   3108,
#   3108,
#   3108,
#   3108,
#   3108,
#   3104,
#   3104,
#   3104,
#   3108,
#   3104,
#   3108,
#   3108,
#   3108,
#   3104,
#   3108,
#   3108,
#   3108,
#   3108,
#   3108,
#   3108,
#   3108,
#   3108,
#   3108,
#   3104,
#   3104,
#   3108,
#   3104,
#   3108,
#   3108,
#   3108,
#   3108,
#   3104,
#   3104,
#   3108,
#   3108,
#   3108,
#   3108,
#   3108,
#   3108,
#   3104,
#   3108,
#   3108,
#   3104,
#   3108,
#   3108,
#   3108,
#   3108],
#  ['Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Capital Regional de Juiz de Fora',
#   'Região Rural da Capital Regional de Juiz de Fora',
#   'Região Rural da Capital Regional de Juiz de Fora',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Capital Regional de Juiz de Fora',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Capital Regional de Juiz de Fora',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Capital Regional de Juiz de Fora',
#   'Região Rural da Capital Regional de Juiz de Fora',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Capital Regional de Juiz de Fora',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Capital Regional de Juiz de Fora',
#   'Região Rural da Capital Regional de Juiz de Fora',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Capital Regional de Juiz de Fora',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Capital Regional de Juiz de Fora',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte',
#   'Região Rural da Metrópole de Belo Horizonte'],
#  ['Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Capital Regional',
#   'Região Rural de Capital Regional',
#   'Região Rural de Capital Regional',
#   'Região Rural de Metrópole',
#   'Região Rural de Capital Regional',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Capital Regional',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Capital Regional',
#   'Região Rural de Capital Regional',
#   'Região Rural de Metrópole',
#   'Região Rural de Capital Regional',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Capital Regional',
#   'Região Rural de Capital Regional',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Capital Regional',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Capital Regional',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole',
#   'Região Rural de Metrópole'],
#  ['Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não'],
#  ['Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não'],
#  ['Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não',
#   'Não'],
#  ['  17,362 ',
#   '  12,977 ',
#   '  14,592 ',
#   '  22,008 ',
#   '  1,294 ',
#   '  26,055 ',
#   '  20,030 ',
#   '  2,398 ',
#   '  11,946 ',
#   '  2,102 ',
#   '  13,783 ',
#   '  7,609 ',
#   '  197,766 ',
#   '  13,268 ',
#   '  14,816 ',
#   '  24,967 ',
#   '  42,075 ',
#   '  9,183 ',
#   '  6,239 ',
#   '  1,875 ',
#   '  59,845 ',
#   '  11,589 ',
#   '  22,628 ',
#   '  27,002 ',
#   '  5,221 ',
#   '  6,867 ',
#   '  2,543 ',
#   '  72,417 ',
#   '  12,252 ',
#   '  10,688 ',
#   '  17,239 ',
#   '  2,377 ',
#   '  5,337 ',
#   '  20,012 ',
#   '  19,785 ',
#   '  92,811 ',
#   '  31,846 ',
#   '  14,909 ',
#   '  12,785 ',
#   '  131,289 ',
#   '  6,358 ',
#   '  37,395 ',
#   '  11,638 ',
#   '  2,061 ',
#   '  32,808 ',
#   '  42,102 ',
#   '  1,915 ',
#   '  22,871 '],
#  ['  63,197 ',
#   '  11,537,468 ',
#   '  9,781 ',
#   '  1,041,129 ',
#   '  2,273 ',
#   '  79,153 ',
#   '  1,636 ',
#   '  684,216 ',
#   '  330,248 ',
#   '  6,425,590 ',
#   '  8,933 ',
#   '  10,095 ',
#   '  245,263 ',
#   '  78,196 ',
#   '  27,081 ',
#   '  62,325 ',
#   '  9,265 ',
#   '  12,648 ',
#   '  2,742 ',
#   '  717,402 ',
#   '  127,311 ',
#   '  21,310 ',
#   '  1,177,398 ',
#   '  1,120,059 ',
#   '  5,187 ',
#   '  714,332 ',
#   '  551,402 ',
#   '  11,372 ',
#   '  45,646 ',
#   '  12,968 ',
#   '  186,986 ',
#   '  4,773 ',
#   '  2,169,067 ',
#   '  1,230,840 ',
#   '  53,085 ',
#   '  787,977 ',
#   '  146,204 ',
#   '  3,132 ',
#   '  3,201 ',
#   '  142,024 ',
#   '  1,376 ',
#   '  16,184 ',
#   '  6,836 ',
#   '  3,257 ',
#   '  131,969 ',
#   '  2,879 ',
#   '  451,207 ',
#   '  3,158,204 '],
#  ['  51,778 ',
#   '  9,924,629 ',
#   '  41,414 ',
#   '  982,042 ',
#   '  18,942 ',
#   '  95,423 ',
#   '  11,431 ',
#   '  703,465 ',
#   '  1,426,466 ',
#   '  15,975,976 ',
#   '  60,658 ',
#   '  25,847 ',
#   '  873,637 ',
#   '  60,032 ',
#   '  104,569 ',
#   '  312,535 ',
#   '  83,218 ',
#   '  56,492 ',
#   '  11,726 ',
#   '  853,103 ',
#   '  337,682 ',
#   '  38,483 ',
#   '  417,784 ',
#   '  1,387,364 ',
#   '  19,083 ',
#   '  273,128 ',
#   '  397,063 ',
#   '  110,563 ',
#   '  53,713 ',
#   '  72,092 ',
#   '  271,161 ',
#   '  29,847 ',
#   '  994,009 ',
#   '  1,242,294 ',
#   '  105,886 ',
#   '  1,419,527 ',
#   '  469,805 ',
#   '  20,830 ',
#   '  19,938 ',
#   '  342,896 ',
#   '  9,325 ',
#   '  68,971 ',
#   '  48,136 ',
#   '  29,146 ',
#   '  195,228 ',
#   '  19,132 ',
#   '  330,185 ',
#   '  3,814,395 '],
#  ['  49,607 ',
#   '  2,212,077 ',
#   '  30,739 ',
#   '  255,486 ',
#   '  19,154 ',
#   '  50,400 ',
#   '  13,531 ',
#   '  404,578 ',
#   '  541,501 ',
#   '  2,843,742 ',
#   '  26,057 ',
#   '  24,953 ',
#   '  328,192 ',
#   '  31,763 ',
#   '  63,305 ',
#   '  292,797 ',
#   '  69,468 ',
#   '  35,269 ',
#   '  17,854 ',
#   '  745,977 ',
#   '  184,678 ',
#   '  32,342 ',
#   '  64,727 ',
#   '  427,749 ',
#   '  25,303 ',
#   '  54,431 ',
#   '  150,920 ',
#   '  57,638 ',
#   '  34,788 ',
#   '  63,769 ',
#   '  138,383 ',
#   '  23,789 ',
#   '  186,023 ',
#   '  399,698 ',
#   '  65,733 ',
#   '  400,212 ',
#   '  108,944 ',
#   '  21,790 ',
#   '  25,287 ',
#   '  139,038 ',
#   '  13,955 ',
#   '  48,237 ',
#   '  26,822 ',
#   '  24,921 ',
#   '  144,208 ',
#   '  24,640 ',
#   '  163,717 ',
#   '  1,109,223 '],
#  ['  181,944 ',
#   '  23,687,150 ',
#   '  96,526 ',
#   '  2,300,665 ',
#   '  41,662 ',
#   '  251,030 ',
#   '  46,627 ',
#   '  1,794,657 ',
#   '  2,310,160 ',
#   '  25,247,410 ',
#   '  109,431 ',
#   '  68,503 ',
#   '  1,644,858 ',
#   '  183,259 ',
#   '  209,771 ',
#   '  692,623 ',
#   '  204,026 ',
#   '  113,592 ',
#   '  38,561 ',
#   '  2,318,357 ',
#   '  709,516 ',
#   '  103,723 ',
#   '  1,682,537 ',
#   '  2,962,175 ',
#   '  54,794 ',
#   '  1,048,758 ',
#   '  1,101,928 ',
#   '  251,989 ',
#   '  146,399 ',
#   '  159,517 ',
#   '  613,770 ',
#   '  60,785 ',
#   '  3,354,437 ',
#   '  2,892,845 ',
#   '  244,488 ',
#   '  2,700,527 ',
#   '  756,798 ',
#   '  60,661 ',
#   '  61,211 ',
#   '  755,246 ',
#   '  31,015 ',
#   '  170,786 ',
#   '  93,432 ',
#   '  59,386 ',
#   '  504,214 ',
#   '  88,753 ',
#   '  947,024 ',
#   '  8,104,693 '],
#  ['  6,005 ',
#   '  4,379,098 ',
#   '  5,797 ',
#   '  215,568 ',
#   '  5,085 ',
#   '  23,248 ',
#   '  1,293 ',
#   '  191,951 ',
#   '  198,959 ',
#   '  5,193,729 ',
#   '  13,124 ',
#   '  4,236 ',
#   '  168,043 ',
#   '  7,912 ',
#   '  18,521 ',
#   '  47,054 ',
#   '  18,208 ',
#   '  9,597 ',
#   '  1,472 ',
#   '  219,672 ',
#   '  72,818 ',
#   '  9,535 ',
#   '  71,318 ',
#   '  512,777 ',
#   '  3,021 ',
#   '  176,128 ',
#   '  248,694 ',
#   '  19,334 ',
#   '  17,593 ',
#   '  10,880 ',
#   '  76,707 ',
#   '  4,779 ',
#   '  828,204 ',
#   '  248,829 ',
#   '  22,456 ',
#   '  421,124 ',
#   '  73,391 ',
#   '  3,829 ',
#   '  3,085 ',
#   '  83,772 ',
#   '  1,122 ',
#   '  9,661 ',
#   '  9,481 ',
#   '  3,785 ',
#   '  75,620 ',
#   '  3,951 ',
#   '  122,227 ',
#   '  1,447,973 '],
#  ['  187,949 ',
#   '  28,066,248 ',
#   '  102,323 ',
#   '  2,516,233 ',
#   '  46,748 ',
#   '  274,278 ',
#   '  47,920 ',
#   '  1,986,608 ',
#   '  2,509,119 ',
#   '  30,441,140 ',
#   '  122,556 ',
#   '  72,739 ',
#   '  1,812,901 ',
#   '  191,172 ',
#   '  228,293 ',
#   '  739,678 ',
#   '  222,234 ',
#   '  123,189 ',
#   '  40,033 ',
#   '  2,538,029 ',
#   '  782,335 ',
#   '  113,258 ',
#   '  1,753,855 ',
#   '  3,474,951 ',
#   '  57,815 ',
#   '  1,224,886 ',
#   '  1,350,623 ',
#   '  271,323 ',
#   '  163,993 ',
#   '  170,397 ',
#   '  690,476 ',
#   '  65,564 ',
#   '  4,182,641 ',
#   '  3,141,674 ',
#   '  266,944 ',
#   '  3,121,650 ',
#   '  830,190 ',
#   '  64,490 ',
#   '  64,296 ',
#   '  839,018 ',
#   '  32,137 ',
#   '  180,447 ',
#   '  102,913 ',
#   '  63,170 ',
#   '  579,834 ',
#   '  92,704 ',
#   '  1,069,251 ',
#   '  9,552,666 '],
#  ['  24,361.53 ',
#   '  63,882.75 ',
#   '  14,898.51 ',
#   '  62,744.25 ',
#   '  12,974.72 ',
#   '  23,595.81 ',
#   '  21,231.85 ',
#   '  36,277.13 ',
#   '  19,512.70 ',
#   '  45,855.10 ',
#   '  23,797.23 ',
#   '  14,449.58 ',
#   '  22,624.78 ',
#   '  26,393.98 ',
#   '  14,923.05 ',
#   '  10,484.15 ',
#   '  14,490.99 ',
#   '  16,511.05 ',
#   '  13,584.21 ',
#   '  14,084.20 ',
#   '  18,174.81 ',
#   '  18,060.59 ',
#   '  157,352.87 ',
#   '  37,279.29 ',
#   '  10,668.94 ',
#   '  249,366.03 ',
#   '  50,123.31 ',
#   '  20,856.56 ',
#   '  20,560.75 ',
#   '  11,053.24 ',
#   '  22,211.81 ',
#   '  13,328.69 ',
#   '  105,889.65 ',
#   '  42,294.45 ',
#   '  17,031.04 ',
#   '  33,220.00 ',
#   '  33,830.05 ',
#   '  14,636.94 ',
#   '  12,905.70 ',
#   '  26,374.26 ',
#   '  16,574.07 ',
#   '  15,691.02 ',
#   '  17,646.22 ',
#   '  16,899.52 ',
#   '  18,361.96 ',
#   '  18,526.03 ',
#   '  32,646.90 ',
#   '  39,862.74 '],
#  ['Indústrias extrativas',
#   'Indústrias de transformação',
#   'Demais serviços',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Agricultura, inclusive apoio à agricultura e a pós colheita',
#   'Demais serviços',
#   'Demais serviços',
#   'Demais serviços',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Indústrias extrativas',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Demais serviços',
#   'Indústrias extrativas',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Indústrias de transformação',
#   'Indústrias de transformação',
#   'Demais serviços',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Demais serviços',
#   'Indústrias de transformação',
#   'Indústrias extrativas',
#   'Demais serviços',
#   'Demais serviços',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Pecuária, inclusive apoio à pecuária',
#   'Demais serviços',
#   'Demais serviços'],
#  ['Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Indústrias extrativas',
#   'Demais serviços',
#   'Indústrias de transformação',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Indústrias extrativas',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Indústrias de transformação',
#   'Demais serviços',
#   'Demais serviços',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Indústrias de transformação',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Indústrias de transformação',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Indústrias extrativas',
#   'Indústrias de transformação'],
#  ['Demais serviços',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Agricultura, inclusive apoio à agricultura e a pós colheita',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Indústrias de transformação',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Indústrias de transformação',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Produção florestal, pesca e aquicultura',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Pecuária, inclusive apoio à pecuária',
#   'Eletricidade e gás, água, esgoto, atividades de gestão de resíduos e descontaminação',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Indústrias extrativas',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Agricultura, inclusive apoio à agricultura e a pós colheita',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Indústrias de transformação',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Indústrias de transformação',
#   'Pecuária, inclusive apoio à pecuária',
#   'Agricultura, inclusive apoio à agricultura e a pós colheita',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Pecuária, inclusive apoio à pecuária',
#   'Produção florestal, pesca e aquicultura',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Comércio e reparação de veículos automotores e motocicletas',
#   'Indústrias de transformação',
#   'Demais serviços',
#   'Administração, defesa, educação e saúde públicas e seguridade social',
#   'Administração, defesa, educação e saúde públicas e seguridade social']]

# %%
#Tratamento dos dados categóricos do PIB do municipio

from sklearn import preprocessing

le = preprocessing.LabelEncoder()
regiao_metropolitana = le.fit(df_1['Região Metropolitana'])
regiao_metropolitana = le.transform(df_1['Região Metropolitana'])
#print(regiao_metropolitana)

le = preprocessing.LabelEncoder()
hierarquia_urbana = le.fit(df_1['Hierarquia Urbana (principais categorias)'])
hierarquia_urbana = le.transform(df_1['Hierarquia Urbana (principais categorias)'])
#print(hierarquia_urbana)

le = preprocessing.LabelEncoder()
mesorregiao = le.fit(df_1['Nome da Mesorregião'])
mesorregiao = le.transform(df_1['Nome da Mesorregião'])
#print(mesorregiao)

le = preprocessing.LabelEncoder()
microrregiao = le.fit(df_1['Nome da Microrregião'])
microrregiao = le.transform(df_1['Nome da Microrregião'])
#print(microrregiao)

le = preprocessing.LabelEncoder()
regiao_geografica_imediata = le.fit(df_1['Nome da Região Geográfica Imediata'])
regiao_geografica_imediata = le.transform(df_1['Nome da Região Geográfica Imediata'])
#print(regiao_geografica_imediata)

le = preprocessing.LabelEncoder()
regiao_geografica_intermediaria = le.fit(df_1['Nome da Região Geográfica Intermediária'])
regiao_geografica_intermediaria = le.transform(df_1['Nome da Região Geográfica Intermediária'])
#print(regiao_geografica_intermediaria)

le = preprocessing.LabelEncoder()
concentracao_urbana = le.fit(df_1['Nome Concentração Urbana'])
concentracao_urbana = le.transform(df_1['Nome Concentração Urbana'])
#print(concentracao_urbana)

le = preprocessing.LabelEncoder()
tipo_concentracao_urbana = le.fit(df_1['Tipo Concentração Urbana'])
tipo_concentracao_urbana = le.transform(df_1['Tipo Concentração Urbana'])
#print(tipo_concentracao_urbana)

le = preprocessing.LabelEncoder()
arranjo_populacional = le.fit(df_1['Nome Arranjo Populacional'])
arranjo_populacional = le.transform(df_1['Nome Arranjo Populacional'])
#print(arranjo_populacional)

le = preprocessing.LabelEncoder()
regiao_rural = le.fit(df_1['Nome da Região Rural'])
regiao_rural = le.transform(df_1['Nome da Região Rural'])
#print(regiao_rural)

le = preprocessing.LabelEncoder()
regiao_rural_nucleo = le.fit(df_1['Região rural (segundo classificação do núcleo)'])
regiao_rural_nucleo = le.transform(df_1['Região rural (segundo classificação do núcleo)'])
#print(regiao_rural_nucleo)

le = preprocessing.LabelEncoder()
nome_municipio = le.fit(df_1['Nome do Município'])
nome_municipio = le.transform(df_1['Nome do Município'])
#print(nome_municipio)

# %%
#Tratamento dos dados numéricos do PIB do municipio

#Valor adicionado bruto dos Serviços a preços correntes - exceto Administração em defesa educação e saúde públicas e seguridade social (R$ 1.000)
agropecuaria = df_1['Valor adicionado bruto da Agropecuária a preços correntes(R$ 1.000)']
industria = df_1['Valor adicionado bruto da Indústria a preços correntes (R$ 1.000)']
servicos = df_1['Valor adicionado bruto dos Serviços a preços correntes - exceto Administração em defesa educação e saúde públicas e seguridade social (R$ 1.000)']

administracao = df_1['Valor adicionado bruto da Administração, defesa, educação e saúde públicas e seguridade social a preços correntes (R$ 1.000)']
bruto_total = df_1['Valor adicionado bruto total a preços correntes (R$ 1.000)']
impostos = df_1['Impostos, líquidos de subsídios, sobre produtos a preços correntes (R$ 1.000)']
precos_correntes = df_1['Produto Interno Bruto a preços correntes (R$ 1.000)']
#per_capita = df_1['Produto Interno Bruto per capita a preços correntes (R$ 1.000)']

agropecuaria_f = []
industria_f = []
servicos_f = []
administracao_f = []
bruto_total_f = []
impostos_f = []
precos_correntes_f = []
#per_capita_f = []

for i in agropecuaria:
    #Expressão regex que remove a segunda vírgula
    i = re.sub('(,[^,]*),', r'\1', i)
    #Remove os espaços embranco e troca o ponto por vírgula
    i = i.replace(' ','').replace(',', '.')
    agropecuaria_f.append(float(i))

for i in industria:
    #Expressão regex que remove a segunda vírgula
    i = re.sub('(,[^,]*),', r'\1', i)
    #Remove os espaços embranco e troca o ponto por vírgula
    i = i.replace(' ','').replace(',', '.')
    industria_f.append(float(i))

for i in servicos:
    #Expressão regex que remove a segunda vírgula
    i = re.sub('(,[^,]*),', r'\1', i)
    #Remove os espaços embranco e troca o ponto por vírgula
    i = i.replace(' ','').replace(',', '.')
    servicos_f.append(float(i))

for i in administracao:
    #Expressão regex que remove a segunda vírgula
    i = re.sub('(,[^,]*),', r'\1', i)
    #Remove os espaços embranco e troca o ponto por vírgula
    i = i.replace(' ','').replace(',', '.')
    administracao_f.append(float(i))

for i in bruto_total:
    #Expressão regex que remove a segunda vírgula
    i = re.sub('(,[^,]*),', r'\1', i)
    #Remove os espaços embranco e troca o ponto por vírgula
    i = i.replace(' ','').replace(',', '.')
    bruto_total_f.append(float(i))

for i in impostos:
    #Expressão regex que remove a segunda vírgula
    i = re.sub('(,[^,]*),', r'\1', i)
    #Remove os espaços embranco e troca o ponto por vírgula
    i = i.replace(' ','').replace(',', '.')
    impostos_f.append(float(i))

for i in precos_correntes:
    #Expressão regex que remove a segunda vírgula
    i = re.sub('(,[^,]*),', r'\1', i)
    #Remove os espaços em branco e troca o ponto por vírgula
    i = i.replace(' ','').replace(',', '.')
    precos_correntes_f.append(float(i))

'''
for i in per_capita:
    #Expressão regex que remove a segunda vírgula
    i = re.sub('(,[^,]*),', r'\1', i)
    #Remove os espaços embranco e troca o ponto por vírgula
    i = i.replace(' ','').replace(',', '.')
    per_capita_f.append(float(i))
'''
# Out:
# "\nfor i in per_capita:\n    #Expressão regex que remove a segunda vírgula\n    i = re.sub('(,[^,]*),', r'\x01', i)\n    #Remove os espaços embranco e troca o ponto por vírgula\n    i = i.replace(' ','').replace(',', '.')\n    per_capita_f.append(float(i))\n"

# %%
#Tratamento dos dados numéricos do IDH dos Municipios

idh = df_3['IDH 2010']
idh_renda = df_3['IDHM Renda 2010']
idh_longevidade = df_3['IDHM Longevidade 2010']
idh_educacao = df_3['IDHM Educação 2010']

idh_f = []
idh_renda_f = []
idh_longevidade_f = []
idh_educacao_f = []

for i in idh:
    idh_f.append(float(i))

for i in idh_renda:
    idh_renda_f.append(float(i))

for i in idh_longevidade:
    idh_longevidade_f.append(float(i))
    
for i in idh_educacao:
    idh_educacao_f.append(float(i))

# %%
#Tratamento dos dados númericos do CAR

app = []
superior_1800 = []
consolidade = []
declividade_maior_45 = []
imoveis = []
pousio = []
topo_morro = []
banhado = []
boda_chapada = []
hidrografia = []
manguezal = []
nascentes = []
reserva_legal = []
restinga = []
servidao_administrativa = []
restrito = []
vegetacao_nativa = []
vereda = []

# %%
#aux = dimensão > 2
aux = []

for i in range(len(regiao_metropolitana)):
    t = []
    #PIB dos municipios
    t.append(nome_municipio[i])
    t.append(regiao_metropolitana[i])
    t.append(hierarquia_urbana[i])
    t.append(mesorregiao[i])
    t.append(microrregiao[i])
    t.append(regiao_geografica_imediata[i])
    t.append(regiao_geografica_intermediaria[i])
    t.append(concentracao_urbana[i])
    t.append(tipo_concentracao_urbana[i])
    t.append(arranjo_populacional[i])
    t.append(regiao_rural[i])
    t.append(regiao_rural_nucleo[i])
    t.append(agropecuaria_f[i])
    t.append(industria_f[i])
    t.append(servicos_f[i])
    t.append(administracao_f[i])
    t.append(bruto_total_f[i])
    t.append(impostos_f[i])
    t.append(precos_correntes_f[i])
    #CAR
    #IDH
    t.append(idh_f[i])
    t.append(idh_renda_f[i])
    t.append(idh_longevidade_f[i])
    t.append(idh_educacao_f[i])
    
    aux.append(t)

# %%
#Método Elbow: Encontrando um valor ideal para o número de clusters

from sklearn.cluster import KMeans
wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'random')
    kmeans.fit(aux)
    print(i, kmeans.inertia_)
    wcss.append(kmeans.inertia_)

#Gráfico da variância em relação ao número de clusters
#Lembrando: maior a variância, maior a dispersão dos dados
plt.plot(range(1,11), wcss)
plt.title('Metodo Elbow')
plt.xlabel('Numero de clusters')
plt.ylabel('WSS') #withim cluster sum of squares
plt.show()
# Out:
# C:\Users\T.i\anaconda3-2\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# 1 13593465.941053882
# 2 9108991.106111852
# 3 4778759.607046388
# 4 3475406.888936217
# 5 2820908.614326814
# 6 2387414.934947812
# 7 1882739.6250226158
# 8 1705357.1567458594
# 9 1438904.3371455134
# 10 954206.8341365145

# %%
#Silhouette Score
#Valor varia entre -1 e +1
#1: Clusters bem mais separados e com valores melhor definidos
#0: Distância entre os clusters formados não é significativa
#-1: Valores dos clusters errados

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

valores_silhouette_scores = []

for i in range(2,15):
    km = KMeans(n_clusters = i, random_state = 42)
    km.fit_predict(aux)
    score = silhouette_score(aux, km.labels_, metric='euclidean')
    
    x = []
    x.append(i)
    x.append(score)
    valores_silhouette_scores.append(x)

print(valores_silhouette_scores)

#Melhor valor encontrado = 4
# Out:
# [[2, 0.5250747991998609], [3, 0.6166440515904487], [4, 0.6260065562742199], [5, 0.6091879342528067], [6, 0.6205445305566991], [7, 0.6296830386267229], [8, 0.5142473247109588], [9, 0.5141737221909132], [10, 0.5110061467350143], [11, 0.5369497490166023], [12, 0.5310140132578282], [13, 0.496165918234219], [14, 0.47611965956493546]]

# %%
#PCA = transforma de n dimensões para uma dimensão m, com n > m

from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
pcaTransformacao = pca.fit_transform(aux)

print(pcaTransformacao)
# Out:
# [[-171.39895972   69.90409027]
#  [-297.57254033 -126.36051741]
#  [-239.03784934  -33.43153355]
#  [ 553.82757481 -316.6976274 ]
#  [-282.88637597 -103.38328882]
#  [-100.02939126  165.26015839]
#  [-289.92795347  -96.63701965]
#  [ 690.69673785 -420.65163441]
#  [  72.09647312 -315.2046078 ]
#  [-294.57905013 -123.78745685]
#  [-219.17000778  -13.34583935]
#  [-263.11546529  -70.01993394]
#  [ 597.26928861 -345.3466655 ]
#  [-163.89140576   71.6980435 ]
#  [-128.35372469  113.1514235 ]
#  [ 302.47542226  725.57221343]
#  [-150.90523793  109.93267049]
#  [-217.64431619  -10.91310531]
#  [-290.96339063 -108.38582717]
#  [ 942.59388846 -488.18157651]
#  [ 329.76373605  762.69891159]
#  [-231.56094117  -23.60400102]
#  [  30.57673579 -214.69104795]
#  [ -18.0596754  -301.38504961]
#  [-275.50702289  -87.70761376]
#  [ 260.78875979 -338.80543985]
#  [ 335.84147952 -348.72553627]
#  [-115.77593103  174.69657804]
#  [-190.38790456   32.37550401]
#  [-179.2904373    46.77954251]
#  [ 257.34922712  636.58187537]
#  [-265.53840214  -79.46077581]
#  [ 718.23179428 -418.79327898]
#  [-105.60039946 -250.0595765 ]
#  [-101.19000944  157.54650976]
#  [ 289.41947165 -410.98345639]
#  [ 424.34501951  820.93530453]
#  [-273.65915601  -78.41874573]
#  [-273.25250824  -78.46027957]
#  [ 347.12532637  834.50303054]
#  [-297.43572836 -117.62850626]
#  [-181.42681796   63.80547823]
#  [-236.34059161  -35.13143284]
#  [-267.23436055  -81.55682838]
#  [ 141.28219531  503.794013  ]
#  [-263.22224938  -39.91930115]
#  [ 403.90599342  334.6315234 ]
#  [-312.63131993 -146.1893668 ]]

# %%
from sklearn.cluster import KMeans
import numpy as np

#Calculando os clusters
kmeans = KMeans(n_clusters = 7, random_state = 0)
cluster = kmeans.fit_predict(aux)

print(cluster)
# Out:
# [1 1 1 3 1 1 1 6 4 1 1 1 3 1 1 0 1 1 1 6 0 1 1 4 1 2 2 1 1 1 0 1 3 4 1 2 0
#  1 1 0 1 1 1 1 0 1 5 1]

# %%
import matplotlib.pyplot as plt

plt.scatter(pcaTransformacao[:,1], pcaTransformacao[:,0], c=cluster)
plt.grid()
plt.scatter(kmeans.cluster_centers_[:,1],kmeans.cluster_centers_[:,0], s=70, c='red') #posicao do centroide do agrupamento
plt.show()

# %%
#Pegando os centroides de cada cluster
centroids = kmeans.cluster_centers_
print(len(centroids))
# Out:
# 7

# %%
#Mostrar valores separados por cluster

from collections import Counter
print(Counter(cluster))
# Out:
# Counter({1: 30, 0: 6, 3: 3, 4: 3, 2: 3, 6: 2, 5: 1})

# %%
#Mostrar o nome das cidades por cluster

cidades = [] #Armazena todos os ids das cidades contidos em aux
city = [] #Converte o id da cidade para o nome real da cidade
c0 = [] #Representa o cluster 0
c1 = [] #Representa o cluster 1
c2 = [] #Representa o cluster 2
c3 = [] #Representa o cluster 3
c4 = [] #Representa o cluster 4
c5 = [] #Representa o cluster 5
c6 = [] #Representa o cluster 6

j = 0 #Contador auxiliar para andar no vetor com os nomes das cidades

#Para cada id que representa uma cidade, eu adiciona no vetor "cidades"
for i in range(len(aux)):
    cidades.append(aux[i][0])

#Converto o id da cidade para o nome da cidade
city = le.inverse_transform(cidades)

#Para cada valor i do "cluster", tem-se o nome da cidade i
#Com isso, é feito um map do nome da cidade com cluster que ela pertence
for i in cluster:
    if i == 0:
        c0.append(city[j])
    elif i == 1:
        c1.append(city[j])
    elif i == 2:
        c2.append(city[j])
    elif i == 3:
        c3.append(city[j])
    elif i == 4:
        c4.append(city[j])
    elif i == 5:
        c5.append(city[j])
    elif i == 6:
        c6.append(city[j])
    j = j + 1
    
print(c0)
print(c1)
print(c2)
print(c3)
print(c4)
print(c5)
print(c6)
# Out:
# ['Esmeraldas', 'Igarapé', 'Mateus Leme', 'Paraopeba', 'Pompéu', 'São Joaquim de Bicas']
# ['Belo Vale', 'Betim', 'Bonfim', 'Cachoeira da Prata', 'Caetanópolis', 'Casa Grande', 'Contagem', 'Cristiano Otoni', 'Crucilândia', 'Desterro de Entre Rios', 'Entre Rios de Minas', 'Felixlândia', 'Florestal', 'Fortuna de Minas', 'Inhaúma', 'Itatiaiuçu', 'Itaverava', 'Lagoa Dourada', 'Maravilhas', 'Mário Campos', 'Moeda', 'Papagaios', 'Pequi', 'Piedade dos Gerais', 'Queluzito', 'Resende Costa', 'Rio Manso', 'São Brás do Suaçuí', 'São José da Varginha', 'Sete Lagoas']
# ['Jeceaba', 'Juatuba', 'Pará de Minas']
# ['Brumadinho', 'Curvelo', 'Ouro Branco']
# ['Conselheiro Lafaiete', 'Itaúna', 'Ouro Preto']
# ['Sarzedo']
# ['Congonhas', 'Ibirité']
