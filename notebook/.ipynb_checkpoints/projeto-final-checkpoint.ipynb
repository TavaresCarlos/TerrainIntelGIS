# %% [markdown]
# ### Resumo

# %%
#Importação das bibliotecas necessárias

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math
from pandas.core.dtypes.api import is_numeric_dtype

from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder

from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.metrics import silhouette_score, accuracy_score, silhouette_samples

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SelectPercentile, f_classif, mutual_info_classif

from sklearn.metrics import davies_bouldin_score

# %%
#Carga dos dados
data1 = pd.read_csv('CAR-recursos-naturais-municipios.csv')
#data2 = pd.read_csv('IDH-cidades.csv')
#Troquei os valores NaN por zero, verificar o impacto disso
data3 = pd.read_csv('IBGE-municipios.csv')

# %%
#Merge dos datasets importados
#data = pd.merge(data1, data2, how='inner', on="Nome do Município")
data = pd.merge(data1, data3, how='inner', on="Nome do Município")
#data = pd.merge(data, data3, how='inner', on="Nome do Município")

data.head()
# Out:
#     Nome do Município   APP  Altitude Superior 1800  Consolidada  \
# 0           Belo Vale  4489                       0          844
# 1               Betim  2664                       0          446
# 2              Bonfim  6133                       0         1749
# 3          Brumadinho  7419                       0          787
# 4  Cachoeira da Prata   330                       0           67
#
#    Declividade Maior 45  Imoveis  Pousio  Topo de Morro  Banhado  \
# 0                     3     1055      47              2        3
# 1                     2      741       9              1        3
# 2                     1     2064      41              1        0
# 3                    15     1177      44              8        1
# 4                     0       61       1              0        1
#
#    Borda Chapada  ...  Total receitas realizadas(2017)  \
# 0              0  ...                         45642.25
# 1              0  ...                       1775733.39
# 2              0  ...                         19095.87
# 3              0  ...                        175543.55
# 4              0  ...                         15260.12
#
#    Total receitas empenhadas(2017)  Mortalidade infantil(2019)  \
# 0                         32123.19                       10.75
# 1                       1363402.09                       13.06
# 2                         19887.69                        0.00
# 3                        165401.05                       17.20
# 4                         12455.95                       25.00
#
#    Internacoes por diarreia(2016)  Estabelecimentos SUS(2009)  \
# 0                             0.8                           5
# 1                             0.1                          73
# 2                             0.0                           4
# 3                             0.3                          27
# 4                             0.0                           2
#
#    Area territorial(2021)  Esgotamento adequado(2010)  \
# 0                 365.923                        48.2
# 1                 343.884                        86.0
# 2                 301.865                        38.5
# 3                 639.434                        65.4
# 4                  61.381                        92.6
#
#    Arborização vias publicas(2010)  Urbanizacao vias publicas(2010)  \
# 0                             67.7                             27.8
# 1                             74.3                             33.4
# 2                             40.9                              9.4
# 3                             59.3                             19.5
# 4                             28.6                              7.2
#
#                       Bioma
# 0            Mata Atlântica
# 1  Cerrado e Mata Atlântica
# 2            Mata Atlântica
# 3            Mata Atlântica
# 4                   Cerrado
#
# [5 rows x 48 columns]

# %%
#Visualização do tipo dos dados
data.dtypes
# Out:
# Nome do Município                                               object
# APP                                                              int64
# Altitude Superior 1800                                           int64
# Consolidada                                                      int64
# Declividade Maior 45                                             int64
# Imoveis                                                          int64
# Pousio                                                           int64
# Topo de Morro                                                    int64
# Banhado                                                          int64
# Borda Chapada                                                    int64
# Hidrografia                                                      int64
# Manguezal                                                        int64
# Nascentes                                                        int64
# Reserva Legal                                                    int64
# Restinga                                                         int64
# Servidão Administrativa                                          int64
# Restrito                                                         int64
# Vegetação Nativa                                                 int64
# Vereda                                                           int64
# População estimada(2021)                                         int64
# População censo(2010)                                            int64
# Densidade demografica(2010)                                    float64
# Salario medio mensal(2019)                                     float64
# Pessoal ocupado(2019)                                            int64
# Populacao ocupada(2019)                                        float64
# Percentual da populacao com renda de ate meio salario(2010)    float64
# Taxa escolarizacao 6 a 14 anos(2010)                           float64
# IDEB anos finais ensino fundamental(2019)                      float64
# IDEB anos finais ensino fundamental(2019).1                    float64
# Matriculas ensino fundamental(2020)                              int64
# Matriculas ensino medio(2020)                                    int64
# Docentes ensino fundamental(2020)                                int64
# Docentes ensino medio(2020)                                      int64
# Numeros estabelecimentos ensino fundamental(2010)                int64
# Numeros estabelecimentos ensino medio(2020)                      int64
# PIB per capita(2019)                                           float64
# Percentual receitas fontes externas(2015)                      float64
# IDHM(2010)                                                     float64
# Total receitas realizadas(2017)                                float64
# Total receitas empenhadas(2017)                                float64
# Mortalidade infantil(2019)                                     float64
# Internacoes por diarreia(2016)                                 float64
# Estabelecimentos SUS(2009)                                       int64
# Area territorial(2021)                                         float64
# Esgotamento adequado(2010)                                     float64
# Arborização vias publicas(2010)                                float64
# Urbanizacao vias publicas(2010)                                float64
# Bioma                                                           object
# dtype: object

# %%
#Remoção dos dados categóricos

df = data.select_dtypes(include=np.number)

# %%
#Visualização dos valores extremos

print(df.max())
print(df.min())
# Out:
# APP                                                              15142.000
# Altitude Superior 1800                                               1.000
# Consolidada                                                       2235.000
# Declividade Maior 45                                                17.000
# Imoveis                                                           2064.000
# Pousio                                                             150.000
# Topo de Morro                                                       27.000
# Banhado                                                             60.000
# Borda Chapada                                                        5.000
# Hidrografia                                                       2069.000
# Manguezal                                                            1.000
# Nascentes                                                         1544.000
# Reserva Legal                                                     2540.000
# Restinga                                                            58.000
# Servidão Administrativa                                            628.000
# Restrito                                                           333.000
# Vegetação Nativa                                                  2837.000
# Vereda                                                           34489.000
# População estimada(2021)                                        673849.000
# População censo(2010)                                           603442.000
# Densidade demografica(2010)                                       3090.330
# Salario medio mensal(2019)                                           4.600
# Pessoal ocupado(2019)                                           212819.000
# Populacao ocupada(2019)                                             85.400
# Percentual da populacao com renda de ate meio salario(2010)         43.900
# Taxa escolarizacao 6 a 14 anos(2010)                               100.000
# IDEB anos finais ensino fundamental(2019)                            7.300
# IDEB anos finais ensino fundamental(2019).1                          6.300
# Matriculas ensino fundamental(2020)                              70893.000
# Matriculas ensino medio(2020)                                    20760.000
# Docentes ensino fundamental(2020)                                 3811.000
# Docentes ensino medio(2020)                                       1407.000
# Numeros estabelecimentos ensino fundamental(2010)                  176.000
# Numeros estabelecimentos ensino medio(2020)                         66.000
# PIB per capita(2019)                                            249366.030
# Percentual receitas fontes externas(2015)                           95.100
# IDHM(2010)                                                           0.761
# Total receitas realizadas(2017)                                1775733.390
# Total receitas empenhadas(2017)                                1632664.770
# Mortalidade infantil(2019)                                          71.430
# Internacoes por diarreia(2016)                                       4.000
# Estabelecimentos SUS(2009)                                         170.000
# Area territorial(2021)                                            3296.200
# Esgotamento adequado(2010)                                          96.200
# Arborização vias publicas(2010)                                     97.200
# Urbanizacao vias publicas(2010)                                     58.200
# dtype: float64
# APP                                                              262.000
# Altitude Superior 1800                                             0.000
# Consolidada                                                       49.000
# Declividade Maior 45                                               0.000
# Imoveis                                                           61.000
# Pousio                                                             0.000
# Topo de Morro                                                      0.000
# Banhado                                                            0.000
# Borda Chapada                                                      0.000
# Hidrografia                                                       34.000
# Manguezal                                                          0.000
# Nascentes                                                          5.000
# Reserva Legal                                                     43.000
# Restinga                                                           0.000
# Servidão Administrativa                                            6.000
# Restrito                                                           0.000
# Vegetação Nativa                                                  47.000
# Vereda                                                             0.000
# População estimada(2021)                                        1948.000
# População censo(2010)                                           1861.000
# Densidade demografica(2010)                                        9.080
# Salario medio mensal(2019)                                         1.500
# Pessoal ocupado(2019)                                            306.000
# Populacao ocupada(2019)                                            9.200
# Percentual da populacao com renda de ate meio salario(2010)       28.200
# Taxa escolarizacao 6 a 14 anos(2010)                              84.200
# IDEB anos finais ensino fundamental(2019)                          0.000
# IDEB anos finais ensino fundamental(2019).1                        0.000
# Matriculas ensino fundamental(2020)                              170.000
# Matriculas ensino medio(2020)                                     47.000
# Docentes ensino fundamental(2020)                                 15.000
# Docentes ensino medio(2020)                                       11.000
# Numeros estabelecimentos ensino fundamental(2010)                  1.000
# Numeros estabelecimentos ensino medio(2020)                        1.000
# PIB per capita(2019)                                           10484.150
# Percentual receitas fontes externas(2015)                          0.000
# IDHM(2010)                                                         0.626
# Total receitas realizadas(2017)                                12289.090
# Total receitas empenhadas(2017)                                11380.680
# Mortalidade infantil(2019)                                         0.000
# Internacoes por diarreia(2016)                                     0.000
# Estabelecimentos SUS(2009)                                         1.000
# Area territorial(2021)                                            35.196
# Esgotamento adequado(2010)                                         2.200
# Arborização vias publicas(2010)                                    4.900
# Urbanizacao vias publicas(2010)                                    0.000
# dtype: float64

# %%
#Como a amplitude dos valores é alta, é necessário normalizar os dados
df_norm = minmax_scale(df)

# %%
#TESTE: verifica que os valores de K variam conforme a execução
#Executa o "Método Elbow" várias vezes a fim de se obter o valor de K que mais se repete

#IMPORTANTE: Algo inovador da minha metodologia

#Necessário definir sempre um mesmo valor de K
import statistics as st

def define_K():
    quantidade = 10
    valores = []
    
    for vez in range(quantidade):
        inicio = 2
        fim = 10
        inercia = []

        for i in range(inicio, fim):
            kmeans = KMeans(n_clusters = i)
            kmeans.fit(df_norm)
            inercia.append(kmeans.inertia_)

        #Cálculo da maior queda do "joelho"
        diferencas = []
        for j in range(2,len(inercia)):
            if j+1 != len(inercia):
                t = []
                m = inercia[j] - inercia[j+1]
                t.append(j+1)
                t.append(m)
                diferencas.append(t)
        valorK = sorted(diferencas, key=lambda diferenca: diferenca[1], reverse=True)
        valores.append((valorK[0][0]))
    #return sum(valores)/quantidade
    return valores

val = define_K()
print(val)
print(st.mode(val))
# Out:
# [4, 3, 3, 4, 3, 3, 5, 4, 3, 3]
# 3

# %%
#TESTE
#Reduzindo a dimensão - atributos com correlação alta

limiar_corr = 0.85
corr = np.abs(data.corr())
correlacoes = corr.to_numpy()

data = data.select_dtypes(include=np.number)

numericas = data.columns.to_list()

numericas_rem = set([])
for i in range(0, len(numericas)-1):
  for j in range(i+1, len(numericas)):
    c = correlacoes[i,j]
    if np.round(c,1) >= limiar_corr:
      # Houve um "empate técnico" de correlação
      vi = np.var(data[numericas[i]])
      vj = np.var(data[numericas[j]])
      if vi >= vj:
        removida = numericas[j]
      else:
        removida = numericas[i]
      numericas_rem = numericas_rem.union(set([removida]))

numericas_sel = set(numericas).difference(numericas_rem)

print(numericas_rem)
print(numericas_sel)

numericas_sel = list(numericas_sel)
numericas_rem = list(numericas_rem)
# Out:
# {'Numeros estabelecimentos ensino medio(2020)', 'Populacao ocupada(2019)', 'População estimada(2021)', 'Consolidada', 'Hidrografia', 'Pessoal ocupado(2019)', 'Docentes ensino fundamental(2020)', 'Reserva Legal', 'Vegetação Nativa', 'Imoveis', 'Docentes ensino medio(2020)', 'Estabelecimentos SUS(2009)', 'Densidade demografica(2010)', 'Matriculas ensino medio(2020)', 'Manguezal', 'População censo(2010)', 'Numeros estabelecimentos ensino fundamental(2010)', 'Matriculas ensino fundamental(2020)', 'Total receitas empenhadas(2017)', 'Salario medio mensal(2019)', 'Servidão Administrativa', 'Nascentes'}
# {'Taxa escolarizacao 6 a 14 anos(2010)', 'Percentual receitas fontes externas(2015)', 'Internacoes por diarreia(2016)', 'APP', 'Restrito', 'IDHM(2010)', 'Esgotamento adequado(2010)', 'Restinga', 'Percentual da populacao com renda de ate meio salario(2010)', 'Borda Chapada', 'Altitude Superior 1800', 'Banhado', 'Declividade Maior 45', 'IDEB anos finais ensino fundamental(2019).1', 'Vereda', 'Topo de Morro', 'Arborização vias publicas(2010)', 'IDEB anos finais ensino fundamental(2019)', 'Pousio', 'PIB per capita(2019)', 'Total receitas realizadas(2017)', 'Area territorial(2021)', 'Mortalidade infantil(2019)', 'Urbanizacao vias publicas(2010)'}

# %%
#PCA = Reduzindo a dimensionalidade dos dados
#OBS.: Reduzindo a dimensão, é perdido a informação dos valores dos dados

pca = PCA(n_components = 2)
pcaTransformacao = pca.fit_transform(df_norm)

# %%
#Algoritmo K-Means

#Calculando os agrupamentos dos dados na dimensão K
K = st.mode(define_K())

#IMPORTANTE: Explicar a escolha de cada valor aqui do parâmetro
kmeans = KMeans(n_clusters = K, init='k-means++', tol=0.0001, verbose=0, random_state = 0, max_iter = 100, copy_x=True, n_init=10, algorithm='elkan')

cluster = kmeans.fit_predict(pcaTransformacao)
#cluster = kmeans.fit_predict(df_norm)

#Centroides de cada um dos clusters gerados
centroids = kmeans.cluster_centers_

#print(cluster)
print(centroids)
# Out:
# [[ 1.96423257  1.10269868]
#  [ 0.20641846 -0.54725499]
#  [-0.48365102  0.42176222]]

# %%
#Algoritmo KMeans sem uso do PCA
#Importância: Pegar os valores dos dados dos centroides dos agrupomentos

df = df.select_dtypes(include=np.number)
min_max = MinMaxScaler()
df_norm_2 = min_max.fit_transform(df)

K = st.mode(define_K())
kmeans = KMeans(n_clusters = K, init='k-means++', tol=0.0001, verbose=0, random_state = 0, max_iter = 100, copy_x=True, n_init=10, algorithm='elkan')
cluster = kmeans.fit_predict(df_norm_2)
centroide_dado_bruto = kmeans.cluster_centers_

valor_referencia_centroide = min_max.inverse_transform(centroide_dado_bruto)

print(valor_referencia_centroide)
# Out:
# [[ 8.18066667e+03  0.00000000e+00  1.49425000e+03  6.08333333e+00
#    1.61900000e+03  4.59166667e+01  6.33333333e+00  1.06666667e+01
#    8.33333333e-02  1.38466667e+03  8.33333333e-02  6.51166667e+02
#    1.64475000e+03  4.91666667e+00  2.88916667e+02  5.96666667e+01
#    1.64350000e+03  1.16666667e+01  5.37127500e+04  4.80137500e+04
#    7.94808333e+01  1.98333333e+00  1.27484167e+04  2.03833333e+01
#    3.47333333e+01  9.84000000e+01  6.59166667e+00  4.97500000e+00
#    6.26000000e+03  1.87983333e+03  3.73333333e+02  1.62250000e+02
#    2.66666667e+01  9.00000000e+00  2.67435617e+04  4.51416667e+01
#    7.02083333e-01  1.31925303e+05  1.21586795e+05  9.37000000e+00
#    1.06666667e+00  2.49166667e+01  8.11611917e+02  6.49416667e+01
#    5.59666667e+01  2.96750000e+01]
#  [ 2.52472727e+03  3.03030303e-02  4.73121212e+02  2.24242424e+00
#    5.78575758e+02  1.99393939e+01  1.72727273e+00  3.54545455e+00
#    3.03030303e-01  4.81969697e+02 -3.46944695e-18  1.78060606e+02
#    5.49818182e+02  1.21212121e-01  9.26060606e+01  1.76969697e+01
#    5.38181818e+02  1.05169697e+03  1.91883939e+04  1.65638485e+04
#    1.45030606e+02  1.96666667e+00  3.53924242e+03  1.96636364e+01
#    3.61666667e+01  9.76272727e+01  6.16363636e+00  4.61515152e+00
#    2.38675758e+03  6.92030303e+02  1.39484848e+02  5.34545455e+01
#    9.27272727e+00  2.42424242e+00  3.09938839e+04  6.59484848e+01
#    6.82060606e-01  5.78047170e+04  5.05334827e+04  1.22721212e+01
#    5.54545455e-01  6.60606061e+00  3.23296697e+02  5.27969697e+01
#    6.64030303e+01  1.91181818e+01]
#  [ 1.95733333e+03  0.00000000e+00  4.53333333e+02  3.00000000e+00
#    6.56000000e+02  1.33333333e+01  2.00000000e+00  1.66666667e+00
#    0.00000000e+00  3.84000000e+02  0.00000000e+00  1.17333333e+02
#    5.33666667e+02  0.00000000e+00  7.93333333e+01  3.33333333e+00
#    5.32333333e+02  2.33333333e+00  4.55941000e+05  3.98561000e+05
#    1.53048333e+03  2.63333333e+00  1.32652667e+05  2.89333333e+01
#    3.21000000e+01  9.80000000e+01  6.16666667e+00  4.76666667e+00
#    5.03603333e+04  1.48463333e+04  2.67700000e+03  1.01133333e+03
#    1.24000000e+02  4.83333333e+01  4.98668633e+04  6.29000000e+01
#    7.55000000e-01  1.38081810e+06  1.19910892e+06  1.24333333e+01
#    1.66666667e-01  1.05000000e+02  3.58519333e+02  9.07000000e+01
#    7.14000000e+01  2.70333333e+01]]

# %%
#Criando dataframe com os valores dos centroides para visualização dos valores 

#IMPORTANTE: Algo inovador da minha metodologia

atributos = df.columns
#Dataframe sem normalização
d = pd.DataFrame(np.round(valor_referencia_centroide, 2), columns=atributos)
display(d)
# Out:
#        APP  Altitude Superior 1800  Consolidada  Declividade Maior 45  \
# 0  8180.67                    0.00      1494.25                  6.08
# 1  2524.73                    0.03       473.12                  2.24
# 2  1957.33                    0.00       453.33                  3.00
#
#    Imoveis  Pousio  Topo de Morro  Banhado  Borda Chapada  Hidrografia  ...  \
# 0  1619.00   45.92           6.33    10.67           0.08      1384.67  ...
# 1   578.58   19.94           1.73     3.55           0.30       481.97  ...
# 2   656.00   13.33           2.00     1.67           0.00       384.00  ...
#
#    IDHM(2010)  Total receitas realizadas(2017)  \
# 0        0.70                        131925.30
# 1        0.68                         57804.72
# 2        0.76                       1380818.10
#
#    Total receitas empenhadas(2017)  Mortalidade infantil(2019)  \
# 0                        121586.80                        9.37
# 1                         50533.48                       12.27
# 2                       1199108.92                       12.43
#
#    Internacoes por diarreia(2016)  Estabelecimentos SUS(2009)  \
# 0                            1.07                       24.92
# 1                            0.55                        6.61
# 2                            0.17                      105.00
#
#    Area territorial(2021)  Esgotamento adequado(2010)  \
# 0                  811.61                       64.94
# 1                  323.30                       52.80
# 2                  358.52                       90.70
#
#    Arborização vias publicas(2010)  Urbanizacao vias publicas(2010)
# 0                            55.97                            29.68
# 1                            66.40                            19.12
# 2                            71.40                            27.03
#
# [3 rows x 46 columns]

# %%
import dataframe_image as dfi

dfi.export(d,"dataframe.jpg", max_cols=-1)

# %%
#Heatmap do dataframe dos centroides

#IMPORTANTE: Algo inovador da minha metodologia


fig, ax = plt.subplots(figsize=(28,10))  
#Dataframe com normalização
sns.heatmap(centroide_dado_bruto, annot=True, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
#Plotagem bidimensional dos agrupamentos formados

plt.scatter(pcaTransformacao[:,1], pcaTransformacao[:,0], c=cluster)
plt.grid()
plt.scatter(centroids[:,1], centroids[:,0], s=20, c='red')
plt.show()

# %%
#Índice de Davies-Bouldin
i = davies_bouldin_score(pcaTransformacao, cluster)
print(i)
# Out:
# 0.7776536659833941

# %%
#Visualização das cidades em cada um dos agrupamentos formados

#IMPORTANTE: Algo inovador da minha metodologia

#REFATORAR ESSE CÓDIGO AQUI

c0 = []
c1 = []
c2 = []
c3 = []
c4 = []
c5 = []
c6 = []

#Valores PCA por cluster
c0_pca = []
c1_pca = []
c2_pca = []
c3_pca = []
c4_pca = []
c5_pca = []
c6_pca = []

indice = 0
cidades = []

for i in cluster:
    if i == 0:
        c0.append(data['Nome do Município'][indice])
        c0_pca.append(pcaTransformacao[indice])
    elif i == 1:
        c1.append(data['Nome do Município'][indice])
        c1_pca.append(pcaTransformacao[indice])
    elif i == 2:
        c2.append(data['Nome do Município'][indice])
        c2_pca.append(pcaTransformacao[indice])
    elif i == 3:
        c3.append(data['Nome do Município'][indice])
        c3_pca.append(pcaTransformacao[indice])
    elif i == 4:
        c4.append(data['Nome do Município'][indice])
        c4_pca.append(pcaTransformacao[indice])
    elif i == 5:
        c5.append(data['Nome do Município'][indice])
        c5_pca.append(pcaTransformacao[indice])
    else:
        c6.append(data['Nome do Município'][indice])
        c6_pca.append(pcaTransformacao[indice])
    indice+=1

if len(c0) != 0:
    cidades.append(c0)
if len(c1) != 0:
    cidades.append(c1)
if len(c2) != 0:
    cidades.append(c2)
if len(c3) != 0:
    cidades.append(c3)
if len(c4) != 0:
    cidades.append(c4)
if len(c5) != 0:
    cidades.append(c5)
if len(c6) != 0:
    cidades.append(c6)

display(cidades)
# Out:
# [['Belo Vale',
#   'Bonfim',
#   'Casa Grande',
#   'Crucilândia',
#   'Desterro de Entre Rios',
#   'Felixlândia',
#   'Itatiaiuçu',
#   'Itaverava',
#   'Jeceaba',
#   'Moeda',
#   'Piedade dos Gerais',
#   'Pompéu',
#   'Queluzito',
#   'Rio Manso'],
#  ['Betim',
#   'Cachoeira da Prata',
#   'Caetanópolis',
#   'Congonhas',
#   'Contagem',
#   'Cristiano Otoni',
#   'Florestal',
#   'Fortuna de Minas',
#   'Ibirité',
#   'Igarapé',
#   'Inhaúma',
#   'Juatuba',
#   'Maravilhas',
#   'Mario Campos',
#   'Mateus Lemes',
#   'Ouro Branco',
#   'Papagaios',
#   'Paraopeba',
#   'Pequi',
#   'São Brás do Suaçuí',
#   'São Joaquim de Bicas',
#   'São José da Varginha',
#   'Sarzedo',
#   'Sete Lagoas'],
#  ['Brumadinho',
#   'Conselheiro Lafaiete',
#   'Curvelo',
#   'Entre Rios de Minas',
#   'Esmeraldas',
#   'Itaúna',
#   'Lagoa Dourada',
#   'Ouro Preto',
#   'Pará de Minas',
#   'Resende Costa']]

# %%
#Função que retorna a distância e o índice da cidade mais próxima do centroide de um agrupamento

import math

def ponto_mais_proximo_centroide(agrupamento_pca, centroide):
    distancia_indice = []
    indice = 0
    for cidade in agrupamento_pca:
        val = []
        x = cidade[0]-centroide[0]
        y = cidade[1]-centroide[1]
        delta = abs(pow(x,2) - pow(y,2))
        val.append(math.sqrt(delta))
        val.append(indice)
        distancia_indice.append(val)
        indice+=1
    
    return min(distancia_indice)


c0_indice = ponto_mais_proximo_centroide(c0_pca, centroids[0])
c1_indice = ponto_mais_proximo_centroide(c1_pca, centroids[1])
c2_indice = ponto_mais_proximo_centroide(c2_pca, centroids[2])

print(c0[c0_indice[1]])
print(c1[c1_indice[1]])
print(c2[c2_indice[1]])

cidades_centroides = [c0[c0_indice[1]], c1[c1_indice[1]], c2[c2_indice[1]]]

#Array com os valores PCA de cada cluster
# Out:
# Itatiaiuçu
# São José da Varginha
# Esmeraldas

# %%
#Dados das cidades mais próximas do centroide de cada agrupamento

for cidade in cidades_centroides:
    display(data.iloc[data[data['Nome do Município'] == cidade].index[0]])
# Out:
# Nome do Município          Itatiaiuçu
# APP                              3850
# Altitude Superior 1800              0
# Consolidada                       845
# Declividade Maior 45                0
# Imoveis                          1071
# Pousio                             18
# Topo de Morro                       1
# Banhado                             0
# Borda Chapada                       0
# Hidrografia                       669
# Manguezal                           0
# Nascentes                         259
# Reserva Legal                    1125
# Restinga                            0
# Servidão Administrativa           184
# Restrito                            4
# Vegetação Nativa                  917
# Vereda                              4
# IDH 2010                        0.677
# IDHM Renda 2010                 0.661
# IDHM Longevidade 2010           0.833
# IDHM Educação 2010              0.563
# Name: 22, dtype: object
# Nome do Município          São José da Varginha
# APP                                        2411
# Altitude Superior 1800                        0
# Consolidada                                 457
# Declividade Maior 45                          0
# Imoveis                                     461
# Pousio                                       10
# Topo de Morro                                 1
# Banhado                                       1
# Borda Chapada                                 0
# Hidrografia                                 508
# Manguezal                                     0
# Nascentes                                   113
# Reserva Legal                               486
# Restinga                                      0
# Servidão Administrativa                      37
# Restrito                                      0
# Vegetação Nativa                            505
# Vereda                                        0
# IDH 2010                                  0.704
# IDHM Renda 2010                           0.682
# IDHM Longevidade 2010                     0.857
# IDHM Educação 2010                        0.597
# Name: 45, dtype: object
# Nome do Município          Esmeraldas
# APP                              8327
# Altitude Superior 1800              0
# Consolidada                      1523
# Declividade Maior 45                0
# Imoveis                          1925
# Pousio                             41
# Topo de Morro                      17
# Banhado                            30
# Borda Chapada                       0
# Hidrografia                      1489
# Manguezal                           0
# Nascentes                         358
# Reserva Legal                    1742
# Restinga                            0
# Servidão Administrativa           336
# Restrito                           23
# Vegetação Nativa                 1759
# Vereda                             10
# IDH 2010                        0.671
# IDHM Renda 2010                 0.649
# IDHM Longevidade 2010           0.822
# IDHM Educação 2010              0.567
# Name: 15, dtype: object

# %%
#REFERÊNCIA

K = valorK[0][0]

pca = PCA(n_components = 2)
pcaTransformacao = pca.fit_transform(df_norm)

kmeans = KMeans(n_clusters = K, random_state = 0, max_iter = 100)
cluster = kmeans.fit_predict(pcaTransformacao)

centroids = kmeans.cluster_centers_

c0 = []
c1 = []
c2 = []
c3 = []
c4 = []
c5 = []
c6 = []
indice = 0

for i in cluster:
    
    if i == 0:
        c0.append(data['Nome do Município'][indice])
    elif i == 1:
        c1.append(data['Nome do Município'][indice])
    elif i == 2:
        c2.append(data['Nome do Município'][indice])
    elif i == 3:
        c2.append(data['Nome do Município'][indice])
    elif i == 4:
        c2.append(data['Nome do Município'][indice])
    elif i == 5:
        c2.append(data['Nome do Município'][indice])
    else:
        c6.append(data['Nome do Município'][indice])
    indice+=1

print(c0)
print(c1)
print(c2)
print(c3)
print(c4)
print(c5)
print(c6)

'''
plt.scatter(pcaTransformacao[:,1], pcaTransformacao[:,0], c=cluster)
plt.grid()
plt.scatter(centroids[:,1], centroids[:,0], s=10, c='red') 

plt.show()
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19116/654960471.py in <module>
#       1 #REFERÊNCIA
#       2
# ----> 3 K = valorK[0][0]
#       4
#       5 pca = PCA(n_components = 2)
#
# NameError: name 'valorK' is not defined
